# %% [markdown]
# 1. Install dependencies

# %%
# !pip install tensorflow pillow numpy matplotlib

# %% [markdown]
# 2. Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from PIL import Image, ImageOps
from google.colab import files

# %% [markdown]
# 3. Load and train CNN (or load saved model)

# %%
# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess data
x_train = x_train.reshape(-1,28,28,1)/255.0
x_test = x_test.reshape(-1,28,28,1)/255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model (5 epochs for demo)
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.1)

# Evaluate
loss, acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {acc*100:.2f}%")

# Save model
model.save('mnist_cnn_model.h5')
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 32ms/step - accuracy: 0.9022 - loss: 0.3226 - val_accuracy: 0.9863 - val_loss: 0.0479
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 31ms/step - accuracy: 0.9855 - loss: 0.0453 - val_accuracy: 0.9898 - val_loss: 0.0397
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9912 - loss: 0.0275 - val_accuracy: 0.9890 - val_loss: 0.0384
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 51s 30ms/step - accuracy: 0.9933 - loss: 0.0206 - val_accuracy: 0.9907 - val_loss: 0.0376
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 82s 30ms/step - accuracy: 0.9954 - loss: 0.0147 - val_accuracy: 0.9902 - val_loss: 0.0369
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9869 - loss: 0.0417
# ...

# %% [markdown]
# 4. Upload your own handwritten digit image

# %%
# Upload image
uploaded = files.upload()

for fn in uploaded.keys():
    # Open uploaded image
    image = Image.open(fn).convert('L')  # convert to grayscale
    image = ImageOps.invert(image)       # invert colors (white digit on black)
    image = image.resize((28,28))        # resize to MNIST size

    # Convert to numpy array
    img_array = np.array(image).reshape(1,28,28,1)/255.0

    # Predict digit
    prediction = model.predict(img_array)
    predicted_digit = np.argmax(prediction)

    # Display image and prediction
    plt.imshow(image, cmap='gray')
    plt.title(f"Predicted Digit: {predicted_digit}")
    plt.axis('off')
    plt.show()
# Out:
#      <input type="file" id="files-2df1390f-d83e-4d57-9b4b-7a96ce36982f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2df1390f-d83e-4d57-9b4b-7a96ce36982f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload image
uploaded = files.upload()

for fn in uploaded.keys():
    # Open uploaded image
    image = Image.open(fn).convert('L')  # convert to grayscale
    image = ImageOps.invert(image)       # invert colors (white digit on black)
    image = image.resize((28,28))        # resize to MNIST size

    # Convert to numpy array
    img_array = np.array(image).reshape(1,28,28,1)/255.0

    # Predict digit
    prediction = model.predict(img_array)
    predicted_digit = np.argmax(prediction)

    # Display image and prediction
    plt.imshow(image, cmap='gray')
    plt.title(f"Predicted Digit: {predicted_digit}")
    plt.axis('off')
    plt.show()
# Out:
#      <input type="file" id="files-6ad1ef48-6808-4dbc-86cd-1b99c6d91753" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ad1ef48-6808-4dbc-86cd-1b99c6d91753">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload image
uploaded = files.upload()

for fn in uploaded.keys():
    # Open uploaded image
    image = Image.open(fn).convert('L')  # convert to grayscale
    image = ImageOps.invert(image)       # invert colors (white digit on black)
    image = image.resize((28,28))        # resize to MNIST size

    # Convert to numpy array
    img_array = np.array(image).reshape(1,28,28,1)/255.0

    # Predict digit
    prediction = model.predict(img_array)
    predicted_digit = np.argmax(prediction)

    # Display image and prediction
    plt.imshow(image, cmap='gray')
    plt.title(f"Predicted Digit: {predicted_digit}")
    plt.axis('off')
    plt.show()
# Out:
#      <input type="file" id="files-29682103-3e8a-40b9-9147-9672fa83c80c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29682103-3e8a-40b9-9147-9672fa83c80c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload image
uploaded = files.upload()

for fn in uploaded.keys():
    # Open uploaded image
    image = Image.open(fn).convert('L')  # convert to grayscale
    image = ImageOps.invert(image)       # invert colors (white digit on black)
    image = image.resize((28,28))        # resize to MNIST size

    # Convert to numpy array
    img_array = np.array(image).reshape(1,28,28,1)/255.0

    # Predict digit
    prediction = model.predict(img_array)
    predicted_digit = np.argmax(prediction)

    # Display image and prediction
    plt.imshow(image, cmap='gray')
    plt.title(f"Predicted Digit: {predicted_digit}")
    plt.axis('off')
    plt.show()
# Out:
#      <input type="file" id="files-41049361-fa4c-491d-8f6d-0a31ad5ede85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41049361-fa4c-491d-8f6d-0a31ad5ede85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
